# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
r = requests.get('https://api.github.com/events')
print(r.text)
import json
json.loads(r.text)
#r.text是沒有排版過的檔案，較難閱讀，而json所讀出來的內容是有經過排版的，較易閱讀
# Out:
# tatuses/{sha}","languages_url":"https://api.github.com/repos/readthedocs/readthedocs.org/languages","stargazers_url":"https://api.github.com/repos/readthedocs/readthedocs.org/stargazers","contributors_url":"https://api.github.com/repos/readthedocs/readthedocs.org/contributors","subscribers_url":"https://api.github.com/repos/readthedocs/readthedocs.org/subscribers","subscription_url":"https://api.github.com/repos/readthedocs/readthedocs.org/subscription","commits_url":"https://api.github.com/repos/readthedocs/readthedocs.org/commits{/sha}","git_commits_url":"https://api.github.com/repos/readthedocs/readthedocs.org/git/commits{/sha}","comments_url":"https://api.github.com/repos/readthedocs/readthedocs.org/comments{/number}","issue_comment_url":"https://api.github.com/repos/readthedocs/readthedocs.org/issues/comments{/number}","contents_url":"https://api.github.com/repos/readthedocs/readthedocs.org/contents/{+path}","compare_url":"https://api.github.com/repos/readthedocs/readthedocs.org/compare/{base}...{head}","merges_url":"https://api.github.com/repos/readthedocs/readthedocs.org/merges","archive_url":"https://api.github.com/repos/readthedocs/readthedocs.org/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/readthedocs/readthedocs.org/downloads","issues_url":"https://api.github.com/repos/readthedocs/readthedocs.org/issues{/number}","pulls_url":"https://api.github.com/repos/readthedocs/readthedocs.org/pulls{/number}","milestones_url":"https://api.github.com/repos/readthedocs/readthedocs.org/milestones{/number}","notifications_url":"https://api.github.com/repos/readthedocs/readthedocs.org/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/readthedocs/readthedocs.org/labels{/name}","releases_url":"https://api.github.com/repos/readthedocs/readthedocs.org/releases{/id}","deployments_url":"https://api.github.com/repos/readthedocs/readthedocs.org/deployments","created_at":"2010-08-16T19:18:06Z","updated_at":"2020-05-28T08:51:15Z","pushed_at":"2020-05-28T08:51:09Z","git_url":"git://github.com/readthedocs/readthedocs.org.git","ssh_url":"git@github.com:readthedocs/readthedocs.org.git","clone_url":"https://github.com/readthedocs/readthedocs.org.git","svn_url":"https://github.com/readthedocs/readthedocs.org","homepage":"https://readthedocs.org/","size":67839,"stargazers_count":5848,"watchers_count":5848,"language":"Python","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":false,"has_pages":false,"forks_count":3137,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":262,"license":{"key":"mit","name":"MIT License","spdx_id":"MIT","url":"https://api.github.com/licenses/mit","node_id":"MDc6TGljZW5zZTEz"},"forks":3137,"open_issues":262,"watchers":5848,"default_branch":"master"}},"_links":{"self":{"href":"https://api.github.com/repos/readthedocs/readthedocs.org/pulls/7137"},"html":{"href":"https://github.com/readthedocs/readthedocs.org/pull/7137"},"issue":{"href":"https://api.github.com/repos/readthedocs/readthedocs.org/issues/7137"},"comments":{"href":"https://api.github.com/repos/readthedocs/readthedocs.org/issues/7137/comments"},"review_comments":{"href":"https://api.github.com/repos/readthedocs/readthedocs.org/pulls/7137/comments"},"review_comment":{"href":"https://api.github.com/repos/readthedocs/readthedocs.org/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/readthedocs/readthedocs.org/pulls/7137/commits"},"statuses":{"href":"https://api.github.com/repos/readthedocs/readthedocs.org/statuses/b447fde25ac1ade13235ec6c02f3f4bb6ebea07a"}},"author_association":"MEMBER"}},"public":true,"created_at":"2020-05-28T09:19:59Z","org":{"id":366329,"login":"readthedocs","gravatar_id":"","url":"https://api.github.com/orgs/readthedocs","avatar_url":"https://avatars.githubusercontent.com/u/366329?"}},{"id":"12462698590","type":"ForkEvent","actor":{"id":13013670,"login":"phixion","display_login":"phixion","gravatar_id":"","url":"https://api.gi ...
# @github.com:readthedocs/readthedocs.org.git',
#       'clone_url': 'https://github.com/readthedocs/readthedocs.org.git',
#       'svn_url': 'https://github.com/readthedocs/readthedocs.org',
#       'homepage': 'https://readthedocs.org/',
#       'size': 67839,
#       'stargazers_count': 5848,
#       'watchers_count': 5848,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 3137,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 262,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 3137,
#       'open_issues': 262,
#       'watchers': 5848,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/readthedocs/readthedocs.org/pulls/7137'},
#      'html': {'href': 'https://github.com/readthedocs/readthedocs.org/pull/7137'},
#      'issue': {'href': 'https://api.github.com/repos/readthedocs/readthedocs.org/issues/7137'},
#      'comments': {'href': 'https://api.github.com/repos/readthedocs/readthedocs.org/issues/7137/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/readthedocs/readthedocs.org/pulls/7137/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/readthedocs/readthedocs.org/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/readthedocs/readthedocs.org/pulls/7137/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/readthedocs/readthedocs.org/statuses/b447fde25ac1ade13235ec6c02f3f4bb6ebea07a'}},
#     'author_association': 'MEMBER'}},
#   'public': True,
#   'created_at': '2020-05-28T09:19:59Z',
#   'org': {'id': 366329,
#    'login': 'readthedocs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/readthedocs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/366329?'}},
#  {'id': '12462698590',
#   'type': 'ForkEvent',
#   'actor': {'id': 13013670,
#    'login': 'phixion',
#    'display_login': 'phixion',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phixion',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13013670?'},
#   'repo': {'id': 86860884,
#    'name': 'compassghost/division-cd',
#    'url': 'https://api.github.com/repos/compassghost/division-cd'},
#   'payload': {'forkee': {'id': 267546286,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNjc1NDYyODY=',
#     'name': 'division-cd',
#     'full_name': 'phixion/division-cd',
#     'private': False,
#     'owner': {'login': 'phixion',
#      'id': 13013670,
#      'node_id': 'MDQ6VXNlcjEzMDEzNjcw',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/13013670?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/phixion',
#      'html_url': 'https://github.com/phixion',
#      'followers_url': 'https://api.github.com/users/phixion/followers',
#      'following_url': 'https://api.github.com/users/phixion/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/phixion/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/phixion/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/phixion/subscriptions',
#      'organizations_url': 'https://api.github.com/users/phixion/orgs',
#      'repos_url': 'https://api.github.com/users/phixion/repos',
#      'events_url': 'https://api.github.com/users/phixion/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/phixion/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/phixion/division-cd',
#     'description': 'Reset Countdown timers for The Division',
#     'fork': True,
#     'url': 'https://api.github.com/repos/phixion/division-cd',
#     'forks_url': 'https://api.github.com/repos/phixion/division-cd/forks',
#     'keys_url': 'https://api.github.com/repos/phixion/division-cd/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/phixion/division-cd/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/phixion/division-cd/teams',
#     'hooks_url': 'https://api.github.com/repos/phixion/division-cd/hooks',
#     'issue_events_url': 'https://api.github.com/repos/phixion/division-cd/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/phixion/division-cd/events',
#     'assignees_url': 'https://api.github.com/repos/phixion/division-cd/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/phixion/division-cd/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/phixion/division-cd/tags',
#     'blobs_url': 'https://api.github.com/repos/phixion/division-cd/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/phixion/division-cd/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/phixion/division-cd/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/phixion/division-cd/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/phixion/division-cd/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/phixion/division-cd/languages',
#     'stargazers_url': 'https://api.github.com/repos/phixion/division-cd/stargazers',
#     'contributors_url': 'https://api.github.com/repos/phixion/division-cd/contributors',
#     'subscribers_url': 'https://api.github.com/repos/phixion/division-cd/subscribers',
#     'subscription_url': 'https://api.github.com/repos/phixion/division-cd/subscription',
#     'commits_url': 'https://api.github.com/repos/phixion/division-cd/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/phixion/division-cd/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/phixion/division-cd/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/phixion/division-cd/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/phixion/division-cd/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/phixion/division-cd/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/phixion/division-cd/merges',
#     'archive_url': 'https://api.github.com/repos/phixion/division-cd/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/phixion/division-cd/downloads',
#     'issues_url': 'https://api.github.com/repos/phixion/division-cd/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/phixion/division-cd/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/phixion/division-cd/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/phixion/division-cd/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/phixion/division-cd/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/phixion/division-cd/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/phixion/division-cd/deployments',
#     'created_at': '2020-05-28T09:19:58Z',
#     'updated_at': '2019-03-09T09:11:13Z',
#     'pushed_at': '2018-07-28T01:16:30Z',
#     'git_url': 'git://github.com/phixion/division-cd.git',
#     'ssh_url': 'git@github.com:phixion/division-cd.git',
#     'clone_url': 'https://github.com/phixion/division-cd.git',
#     'svn_url': 'https://github.com/phixion/division-cd',
#     'homepage': None,
#     'size': 7660,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'gpl-3.0',
#      'name': 'GNU General Public License v3.0',
#      'spdx_id': 'GPL-3.0',
#      'url': 'https://api.github.com/licenses/gpl-3.0',
#      'node_id': 'MDc6TGljZW5zZTk='},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-05-28T09:19:59Z'},
#  {'id': '12462698579',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 752680,
#    'login': 'umbobabo',
#    'display_login': 'umbobabo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/umbobabo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/752680?'},
#   'repo': {'id': 133928511,
#    'name': 'Financial-Times/n-conversion-forms',
#    'url': 'https://api.github.com/repos/Financial-Times/n-conversion-forms'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Financial-Times/n-conversion-forms/issues/431',
#     'repository_url': 'https://api.github.com/repos/Financial-Times/n-conversion-forms',
#     'labels_url': 'https://api.github.com/repos/Financial-Times/n-conversion-forms/issues/431/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Financial-Times/n-conversion-forms/issues/431/comments',
#     'events_url': 'https://api.github.com/repos/Financial-Times/n-conversion-forms/issues/431/events',
#     'html_url': 'https://github.com/Financial-Times/n-conversion-forms/pull/431',
#     'id': 626321482,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDI0MzMxOTQ4',
#     'number': 431,
#     'title': 'feat: update delivery instructions prompt (ACC-377)',
#     'user': {'login': 'tolujimoh',
#      'id': 17183724,
#      'node_id': 'MDQ6VXNlcjE3MTgzNzI0',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/17183724?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tolujimoh',
#      'html_url': 'https://github.com/tolujimoh',
#      'followers_url': 'https://api.github.com/users/tolujimoh/followers',
#      'following_url': 'https://api.github.com/users/tolujimoh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tolujimoh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tolujimoh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tolujimoh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tolujimoh/orgs',
#      'repos_url': 'https://api.github.com/users/tolujimoh/repos',
#      'events_url': 'https://api.github.com/users/tolujimoh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tolujimoh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'tolujimoh',
#      'id': 17183724,
#      'node_id': 'MDQ6VXNlcjE3MTgzNzI0',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/17183724?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tolujimoh',
#      'html_url': 'https://github.com/tolujimoh',
#      'followers_url': 'https://api.github.com/users/tolujimoh/followers',
#      'following_url': 'https://api.github.com/users/tolujimoh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tolujimoh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tolujimoh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tolujimoh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tolujimoh/orgs',
#      'repos_url': 'https://api.github.com/users/tolujimoh/repos',
#      'events_url': 'https://api.github.com/users/tolujimoh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tolujimoh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'tolujimoh',
#       'id': 17183724,
#       'node_id': 'MDQ6VXNlcjE3MTgzNzI0',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/17183724?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tolujimoh',
#       'html_url': 'https://github.com/tolujimoh',
#       'followers_url': 'https://api.github.com/users/tolujimoh/followers',
#       'following_url': 'https://api.github.com/users/tolujimoh/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tolujimoh/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tolujimoh/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tolujimoh/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tolujimoh/orgs',
#       'repos_url': 'https://api.github.com/users/tolujimoh/repos',
#       'events_url': 'https://api.github.com/users/tolujimoh/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tolujimoh/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2020-05-28T08:30:29Z',
#     'updated_at': '2020-05-28T09:19:59Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/Financial-Times/n-conversion-forms/pulls/431',
#      'html_url': 'https://github.com/Financial-Times/n-conversion-forms/pull/431',
#      'diff_url': 'https://github.com/Financial-Times/n-conversion-forms/pull/431.diff',
#      'patch_url': 'https://github.com/Financial-Times/n-conversion-forms/pull/431.patch'},
#     'body': '### Description\r\nThis PR updates the Prompt for Delivery Instructions Component\r\n\r\n### Screenshots\r\n\r\n| Before |\r\n| ------ |\r\n<img width="382" alt="Screenshot 2020-05-26 at 11 20 52" src="https://user-images.githubusercontent.com/17183724/83117570-24863c80-a0c5-11ea-815a-bf0b4b21bd29.png">\r\n\r\n| After |\r\n| ----- |\r\n<img width="459" alt="Screenshot 2020-05-28 at 09 29 36" src="https://user-images.githubusercontent.com/17183724/83118104-d291e680-a0c5-11ea-9570-974f4f3f414c.png">\r\n\r\n\r\n### Reminder\r\nHave you completed these common tasks (remove those that don\'t apply)?\r\n\r\n- [ ] **Documentation** updated or created\r\n- [x] **Tests** written for new or updated for existing functionality\r\n- [ ] **Demos** updated to use this change\r\n- [ ] **Accessibility** checked for screen readers and contrast\r\n- [ ] **Design Review** ran past the designer \r\n- [ ] **Product Review** ran past the product owner\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/Financial-Times/n-conversion-forms/issues/comments/635224438',
#     'html_url': 'https://github.com/Financial-Times/n-conversion-forms/pull/431#issuecomment-635224438',
#     'issue_url': 'https://api.github.com/repos/Financial-Times/n-conversion-forms/issues/431',
#     'id': 635224438,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYzNTIyNDQzOA==',
#     'user': {'login': 'umbobabo',
#      'id': 752680,
#      'node_id': 'MDQ6VXNlcjc1MjY4MA==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/752680?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/umbobabo',
#      'html_url': 'https://github.com/umbobabo',
#      'followers_url': 'https://api.github.com/users/umbobabo/followers',
#      'following_url': 'https://api.github.com/users/umbobabo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/umbobabo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/umbobabo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/umbobabo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/umbobabo/orgs',
#      'repos_url': 'https://api.github.com/users/umbobabo/repos',
#      'events_url': 'https://api.github.com/users/umbobabo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/umbobabo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-05-28T09:19:59Z',
#     'updated_at': '2020-05-28T09:19:59Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '@nickramsbottom FYI This change has been asked by Nevena and will be visible also in the Buy Flow when you will update the package.'}},
#   'public': True,
#   'created_at': '2020-05-28T09:19:59Z',
#   'org': {'id': 3502508,
#    'login': 'Financial-Times',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Financial-Times',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3502508?'}},
#  {'id': '12462698582',
#   'type': 'IssuesEvent',
#   'actor': {'id': 33403149,
#    'login': 'vonlu3',
#    'display_login': 'vonlu3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vonlu3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33403149?'},
#   'repo': {'id': 110467581,
#    'name': 'nuxt-community/nuxt-i18n',
#    'url': 'https://api.github.com/repos/nuxt-community/nuxt-i18n'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/nuxt-community/nuxt-i18n/issues/739',
#     'repository_url': 'https://api.github.com/repos/nuxt-community/nuxt-i18n',
#     'labels_url': 'https://api.github.com/repos/nuxt-community/nuxt-i18n/issues/739/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/nuxt-community/nuxt-i18n/issues/739/comments',
#     'events_url': 'https://api.github.com/repos/nuxt-community/nuxt-i18n/issues/739/events',
#     'html_url': 'https://github.com/nuxt-community/nuxt-i18n/issues/739',
#     'id': 626305778,
#     'node_id': 'MDU6SXNzdWU2MjYzMDU3Nzg=',
#     'number': 739,
#     'title': 'Command for extracting / collecting messages',
#     'user': {'login': 'vonlu3',
#      'id': 33403149,
#      'node_id': 'MDQ6VXNlcjMzNDAzMTQ5',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/33403149?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vonlu3',
#      'html_url': 'https://github.com/vonlu3',
#      'followers_url': 'https://api.github.com/users/vonlu3/followers',
#      'following_url': 'https://api.github.com/users/vonlu3/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vonlu3/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vonlu3/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vonlu3/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vonlu3/orgs',
#      'repos_url': 'https://api.github.com/users/vonlu3/repos',
#      'events_url': 'https://api.github.com/users/vonlu3/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vonlu3/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2020-05-28T08:06:16Z',
#     'updated_at': '2020-05-28T09:19:59Z',
#     'closed_at': '2020-05-28T09:19:59Z',
#     'author_association': 'NONE',
#     'body': "### Problem\r\nIn most projects the translatable strings nor the translations are not ready at the beginning. As you progress with the project you define the translatable strings but forgetting or just don't want to add the strings to the translation file each time. After finishing the base layout or a feature you have to go trough the files and searching for all translatable strings manually. \r\n\r\n### Solution\r\nIt would be really nice to have a command for extracting / collecting all translatable strings from the *.vue files and write it to the translation files in each configured language. Of course the script should not overwrite existing translations nor delete unused ones. \r\n\r\nAnother use case is to extract all messages in the CI process and send it to a translation API. In the translation API the customer can translate the strings in a fancy interface. Then we can load the translation from the API while generating the static pages or serving requests in SSR mode.\r\n\r\n### Alternatives\r\nJust be more disciplined and update the translation files by hand 😄 .\r\n\r\n### Additional context\r\nRepo for same feature in vue-i18n:\r\nhttps://github.com/pixari/vue-i18n-extract\r\n\r\n"}},
#   'public': True,
#   'created_at': '2020-05-28T09:19:59Z',
#   'org': {'id': 29566738,
#    'login': 'nuxt-community',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/nuxt-community',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29566738?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json 
r = requests.get('https://cat-fact.herokuapp.com/facts')

json.loads(r.text)
# Out:
# id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e83ff18f53272001515690c',
#    'type': 'cat',
#    'text': 'Cats are capable of walking very precisely because, like all felines, they directly register; that is, they place each hind paw (almost) directly in the print of the corresponding fore paw, minimizing noise and visible tracks. This also provides sure footing for their hind paws when they navigate rough terrain.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e80e7cc2d4b850015003072',
#    'type': 'cat',
#    'text': 'Cats can climb on trees faster than squirels.',
#    'user': {'_id': '5e80e6c72d4b85001500306e',
#     'name': {'first': 'Łukasz', 'last': 'Wiktorko'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eafdaf354ad960017b3703d',
#    'type': 'cat',
#    'text': 'Yjyyu.',
#    'user': {'_id': '5eafdad954ad960017b37038',
#     'name': {'first': 'Lulu', 'last': 'Dauphin'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ebbf5dd8046d00017776020',
#    'type': 'cat',
#    'text': 'Cats are fat, sometimes.',
#    'user': {'_id': '5ebbf5cd8046d0001777601f',
#     'name': {'first': 'George', 'last': 'Miguel'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec4aad30c796a00174d7b26',
#    'type': 'cat',
#    'text': 'Sss.',
#    'user': {'_id': '5ec4a7d60c796a00174d7b25',
#     'name': {'first': 'Minh', 'last': 'Nguyễn'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec93d1de11bba0017c67e19',
#    'type': 'cat',
#    'text': 'In a sense, cats can see in the dark.',
#    'user': {'_id': '5ec93c89e11bba0017c67e18',
#     'name': {'first': 'Mandy', 'last': 'c'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb032ab0d92c0017cab214',
#    'type': 'cat',
#    'text': 'Cats are the best pets.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb0333b0d92c0017cab215',
#    'type': 'cat',
#    'text': 'Hello cats.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecdda946253f20017f53ec5',
#    'type': 'cat',
#    'text': 'Cats love womans, dog loves mans.',
#    'user': {'_id': '5ecdda686253f20017f53ec4',
#     'name': {'first': 'Jorge Alberto', 'last': 'Gil Rendon'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ece7253a0d2ec00178ae28c',
#    'type': 'cat',
#    'text': 'Cat is cat.',
#    'user': {'_id': '5eccdd64ba0a92001760e263',
#     'name': {'first': 'Paulius', 'last': 'Bertašius'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ece9fa9a0d2ec00178ae28e',
#    'type': 'cat',
#    'text': 'Z.',
#    'user': {'_id': '5eccdd64ba0a92001760e263',
#     'name': {'first': 'Paulius', 'last': 'Bertašius'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ea7496761cd4d0017498a94',
#    'type': 'cat',
#    'text': 'Ancient sailors believed that cats were magic and would often risk their own lives, even in an "every man for himself" situation, to save a cat from a sinking ship. All ships had at least one ship\'s cat as cats would eat the rats that have always plagued ships. The ship\'s cat would often be given a rank and sailors would generally take excessively good care of their cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eaafca69105ce00177573de',
#    'type': 'cat',
#    'text': 'Cats sleep most of the time.',
#    'user': {'_id': '5ea977d1cd53d20017d7d8b2',
#     'name': {'first': 'Quang', 'last': 'Pham'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
